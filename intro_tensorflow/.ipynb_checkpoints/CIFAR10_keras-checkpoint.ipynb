# %%
import tensorflow as tf
from tensorflow import keras 
import sklearn.preprocessing as sklpp

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

# import tensorflow as tf
# import tensorflow.keras as keras
# import numpy as np
# import matplotlib.pyplot as plt 
# import sklearn.preprocessing as skpp
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %% [markdown]
# # Load data

# %%
(x_train_raw, y_train_raw), (x_test_raw, y_test_raw) = keras.datasets.cifar10.load_data()

# %%
## Explore dataset

# helpers
def get_labels():
    return ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck' ] 

def plot_images(x, y, 
                class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog',
               'frog', 'horse', 'ship', 'truck' ],
               fig_size = (10,10)):
    # TODO: check inputs conform to function requirements 
    # _isvalid(x)
    # _isvalid(y)
    n_rows = 3
    n_cols = 3 
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize = fig_size)
    axes = axes.flatten()

    for img_idx, ax in enumerate( axes ): 
        ax.imshow(x[img_idx, :,:,:]) 
        ax.set_title(f'{y[img_idx][0] }:  {class_names[ y[img_idx][0] ]}' )

images_idxs = np.random.choice(1000,9) 
plot_images(x_train[images_idxs,], y_train[images_idxs,], fig_size = (15,15))

# %%
n_features = x_train[0,].size
print(n_features)
# Out:
# 3072

# %%
type(x_train[0,0,0,0])
# Out:
# numpy.uint8

# %% [markdown]
# ## Preprocess data

# %%
def scale_data(x):
    MinMax = sklpp.MinMaxScaler( )
    x_shape = x.shape
    x_scaled = x.reshape((-1,2), order = 'C')
    x_scaled= ( MinMax.fit_transform(x_scaled) ).reshape(xtrain_shape, order = 'C')
    
    return x_scaled
